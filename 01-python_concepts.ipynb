# %% [markdown]
# ### Python Programming Concepts

# %% [markdown]
# #### 1. Create a variable to store the value 500 for sales

# %%
sales = 500

# %% [markdown]
# #### 2. Create a variable to store several values:
# * sales: 500, 475, 625
# * integers 1 - 9

# %%
sales = [500, 475, 625]

# %%
integers = [1,2,3,4,5,6,7,8,9] 
#or you can do : integers = list(range(1,10))
integers1 = list(range(1,10))
print(integers1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# #### 3. Create a variable to store the names and email addresses for a number of customers
# * John, john@some.com; Ann, ann@some.com

# %%
customers = [
{'name':'john', 'email':'john@some.com'},
{'name': 'ann', 'email':'ann@some.com'}
]
customers[0]['name']
# Out:
# 'john'

# %% [markdown]
# #### 4. Use Python to generate a random value based on each of following:
# 1. between 0 and 1
# 2. the standard normal distribution (rounded to two decimal places)
# 3. a value between 1 and 10
# 4. either H or T

# %%
import random
value = random.random()
value

## or you can say - 
#from random import random 
#random
# Out:
# 0.6485351499806673

# %%
#can use either gauss or normal random.gauss(0,1)
rounded = round(value,2)
rounded
# Out:
# 0.65

# %%
import random
value1_10 = random.randint(1,10)
value1_10
# Out:
# 8

# %%
import random
toss = random.choice(["H", "T"])
toss
# Out:
# 'H'

# %% [markdown]
# #### 5. Use Python to determine your current working directory

# %%
import os
current_working_directory = os.getcwd()
print(current_working_directory)
# Out:
# C:\Users\Vanshika\OIM7502_F25

# %% [markdown]
# #### 6. Use Python to determine how many days until New Year's Day

# %%
from datetime import date
todays_date = date.today()
new_years = date(todays_date.year +1, 1, 1)
days_till_ny = (new_years - todays_date).days

print(days_till_ny, "days left till new years")
# Out:
# 110 days left till new years

# %% [markdown]
# #### 7. Write a short program that displays the future value of 1,000 earning 5%  at the end of each year for the next 5 years

# %%
amount = 1000
rate = 0.05

for year in range(1,6):
    future_value = amount * (1 + rate) ** year

print(future_value)
# Out:
# 1276.2815625000003

# %% [markdown]
# #### 8. Write a short program that prompts a user to enter a stock symbol and press enter. Add each symbol entered to a variable. The program should run until the user presses the enter key without entering anything (empty string)

# %%
stock_symbol = []
print("enter stock symbol. enter without typing anything to stop.")

while True: 
    symbol= input("enter a stock symbol : ")
    
    if symbol == "":
        break
stock_symbol.append(symbol)
print(stock_symbol)
# Out:
# enter stock symbol. enter without typing anything to stop.
# enter a stock symbol :  s
# enter a stock symbol :  s
# enter a stock symbol :
# ['']

# %% [markdown]
# #### 9. Write the code necessary to calculate the sum of the square differences of a group of values :
# 58, 32, 37, 41, 36, 36, 54, 37, 25, 53
# ##### $\Sigma $(${x}$ - $\bar{x}$)$^2$

# %%
values =[58, 32, 37, 41, 36, 36, 54, 37, 25, 53]

mean = sum(values) / len(values)

sum_squared_difference = sum((x - mean) ** 2 for x in values)

print(mean, sum_squared_difference)
# Out:
# 40.9 1020.9

# %% [markdown]
# #### 10. Opening, reading and writing files

# %%
file = open("C:/Users/Vanshika/Desktop/Adv. prog assignment 1.txt","r")
content = file.read()
print(content)

file = open("C:/Users/Vanshika/Desktop/Adv. prog assignment 1.txt","w")
file.write("Line 2 in the sample file")
file.close()

file = open("C:/Users/Vanshika/Desktop/Adv. prog assignment 1.txt","r")
content = file.read()
print(content)
# Out:
# Sample file for Advanced Programming assignment 1.

# %% [markdown]
# #### 11. Create a function the will simulate rolling two die and return the value of each and and the sum

# %%
import random
def roll_dices():
    die1 = random.randint(1,6)
    die2 = random.randint(1,6)
    total = die1 + die2
    return die1, die2, total
print(roll_dices())
# Out:
# (4, 1, 5)

# %% [markdown]
# #### 12. Write the code needed to evaluate whether a value in a group of values is negative or postive and prints an approriate message, i.e. postive, negative
# -1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2

# %%
values = [-1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2]
for num in values:
    if num > 0:
        print("Positive")
    elif num < 0:
        print("Negative")
    else: 
        print("Zero")
# Out:
# Negative
# Positive
# Positive
# Positive
# Negative
# Positive
# Negative
# Positive
# Negative
# Positive

# %% [markdown]
# #### 14.  Complete the following:
# 1. Write a program that generates 500 random integers from 1 to n, for example, the first integer will be 1 the second will be 1 or 2, the fifth between 1 and 5, and so on.
# 2. The program should write each integer to a file
# 3. Once all integers are written close the file
#
# ##### Part 2
# 1. Open and read the file into a list
# 2. Create a line plot of the data

# %%
import random
with open("numbers.txt", "w") as file:
    for x in range(1,501):
        integer = random.randint(1,x)
        file.write(str(integer) + "\n")

print("500 random integers from 1 to n written in numbers.txt")
# Out:
# 500 random integers from 1 to n written in numbers.txt

# %%
import matplotlib.pyplot as plt
with open("numbers.txt","r") as file: 
    data = [int(line.strip()) for line in file]
plt.figure(figsize=(10,8))
plt.plot(data, linestyle='-', color='red', label='500 Random Integers')

plt.title("Line plot of 500 random integers")
plt.xlabel('Index (1 to 500)')
plt.ylabel('randowm value')

plt.legend()
plt.grid(True)
plt.show()
